# %% [markdown]
# # WeatherPy
#
# ### OpenWeatherMap API Call
#
#
# This file contains the code for the following:
# - Random selection of at least 500 unique cities based on latitude and longitude using citipy
# - Weather check on each of the cities using a series of successive API calls from OpenWeatherMap.org
# - A print log of each city as it's being processed with the city number and city name
# - Weather data was collected from OpenWeatherMap.org on September 23, 2019 around 22:44 (PDT).

# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint
from scipy.stats import linregress

# Import API key

from api_keys import weather_api_key

# Incorporate citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)

output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding latitudes,longitudes, and cities

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to our cities list
    
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficent count

len(cities)
# Out:
# 606

# %%
# Create list of sample cities to test API call on

sample_cities = ["Paris", "London", "Oslo", "Beijing", "Mumbai", "Manila", "New York", "Seattle", "Dallas", "Taiwan"]

# Create empty list to store temperature data

temp = []

# Define end URL for the API call

url = "http://api.openweathermap.org/data/2.5/weather?"

# Specify the unit of measure 

units = "metric"

# Build query URL

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Create a for loop to request info from openweathermap.org of the sample cities list created above

for city in sample_cities:
    response = requests.get(query_url + city).json()
    temp.append(response['main']['temp'])

# Print the temperature info    
    
print(f"The temperature information received is: {temp}")
# Out:
# The temperature information received is: [15.21, 16.08, 8.46, 31.8, 30.4, 31.78, 22.18, 14.82, 27.63, 30.03]

# %%
# Specify the unit of measure as "imperial" so that the temperature is in Fahrenheit and wind speed is in miles/hour

temperature_units = "imperial"

# Set base URL and query URL

base_url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{base_url}appid={weather_api_key}&units={temperature_units}&q="

# Create empty lists for each of the variables so that the data collected can be appended to the list later

city_list = []
cloudiness_list = []
country_list = []
date_list = [] 
humidity_list = []   
lat_list = []           
lng_list = []         
max_temp_list = []      
wind_speed_list = []

# Set the record number and set number so that the print log can keep count as each city is being processed

record_number = 0
set_number = 1

# Print title and a dash separator 

print("Beginning Data Retrieval")
print("------------------------------------")

# Create a for loop to request the information for each city from openweathermap.org

for city in cities:
    try:
        
        # Set up the API request call
        
        response = requests.get(query_url+city.replace(" ","&")).json()
        
        # Append appropriate data to the lists created above
        
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response["main"]["temp_max"])
        wind_speed_list.append(response["wind"]["speed"])
        
        # Also set up the record and set numbers so that they will print appropriately 
        
        if record_number > 49:
            record_number = 1
            set_number += 1
            city_list.append(city)
            print("------------------------------------")
        else:
            record_number += 1
            city_list.append(city)
        print(f"Processing Record {record_number} of Set {set_number} | {city}")
        
        # Add an print exception for when the city is not found
        
    except Exception:
        print("City not found. Skipping...")

# When processing is complete, print "Data Retrieval Complete" with dash separators

print("------------------------------------")
print("Data Retrieval Complete")
print("------------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | kavaratti
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | weinan
# Processing Record 6 of Set 1 | hamilton
# Processing Record 7 of Set 1 | prince rupert
# Processing Record 8 of Set 1 | aswan
# Processing Record 9 of Set 1 | ahipara
# Processing Record 10 of Set 1 | carnarvon
# City not found. Skipping...
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | codrington
# Processing Record 17 of Set 1 | qingdao
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | ambilobe
# City not found. Skipping...
# Processing Record 21 of Set 1 | shivrajpur
# Processing Record 22 of Set 1 | sinnamary
# Processing Record 23 of Set 1 | carutapera
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | dingle
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set 1 | lashio
# Processing Record 28 of Set 1 | karratha
# Processing Record 29 of Set 1 | lohr
# City not found. Skipping...
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | cockburn harbour
# Processing Record 32 of Set 1 | somerville
# Processing Record 33 of Set 1 | kamina
# Processing Record 34 of Set 1 | ixtapa
# Processing Record 35 of Set 1 | turukhansk
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | fortuna
# Processing Record 39 of Set 1 | norman wells
# Processing Record 40 of Set 1 | buraydah
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | marawi
# Processing Record 43 of Set 1 | aasiaat
# Processing Record 44 of Set 1 | taksimo
# City not found. Skipping...
# Processing Record 45 of Set 1 | sorong
# Processing Record 46 of Set 1 | lima
# Processing Record 47 of Set 1 | klaksvik
# Processing Record 48 of Set 1 | bathsheba
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | axim
# ------------------------------------
# Processing Record 1 of Set 2 | kodiak
# Processing Record 2 of Set 2 | kuching
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | wukari
# City not found. Skipping...
# Processing Record 6 of Set 2 | uglegorsk
# Processing Record 7 of Set 2 | makasar
# Processing Record 8 of Set 2 | constitucion
# Processing Record 9 of Set 2 | mahebourg
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | hofn
# Processing Record 12 of Set 2 | bulqize
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | ashtian
# Processing Record 16 of Set 2 | kota
# City not found. Skipping...
# Processing Record 17 of Set 2 | honiara
# Processing Record 18 of Set 2 | provideniya
# Processing Record 19 of Set 2 | kaminskiy
# Processing Record 20 of Set 2 | lorengau
# Processing Record 21 of Set 2 | hay river
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | ojinaga
# Processing Record 24 of Set 2 | vila velha
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | sendhwa
# Processing Record 27 of Set 2 | bahile
# Processing Record 28 of Set 2 | west wendover
# Processing Record 29 of Set 2 | pangnirtung
# Processing Record 30 of Set 2 | tarakan
# Processing Record 31 of Set 2 | stranda
# City not found. Skipping...
# Processing Record 32 of Set 2 | eenhana
# Processing Record 33 of Set 2 | saldanha
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | kerouane
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | galle
# Processing Record 39 of Set 2 | vestmanna
# Processing Record 40 of Set 2 | makakilo city
# City not found. Skipping...
# Processing Record 41 of Set 2 | ponta do sol
# City not found. Skipping...
# Processing Record 42 of Set 2 | coquimbo
# Processing Record 43 of Set 2 | inirida
# Processing Record 44 of Set 2 | pilar do sul
# Processing Record 45 of Set 2 | leh
# Processing Record 46 of Set 2 | porto velho
# Processing Record 47 of Set 2 | marsa matruh
# City not found. Skipping...
# Processing Record 48 of Set 2 | ilhabela
# Processing Record 49 of Set 2 | beringovskiy
# Processing Record 50 of Set 2 | bredasdorp
# ------------------------------------
# Processing Record 1 of Set 3 | lata
# Processing Record 2 of Set 3 | mount gambier
# Processing Record 3 of Set 3 | zhangye
# Processing Record 4 of Set 3 | tuatapere
# Processing Record 5 of Set 3 | damghan
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | chimbote
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | ayan
# Processing Record 10 of Set 3 | bilma
# Processing Record 11 of Set 3 | lavrentiya
# Processing Record 12 of Set 3 | thompson
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | cape town
# City not found. Skipping...
# Processing Record 15 of Set 3 | new norfolk
# City not found. Skipping...
# Processing Record 16 of Set 3 | longyearbyen
# Processing Record 17 of Set 3 | atar
# Processing Record 18 of Set 3 | mikkeli
# Processing Record 19 of Set 3 | kajaani
# Processing Record 20 of Set 3 | kununurra
# Processing Record 21 of Set 3 | merrill
# Processing Record 22 of Set 3 | punta arenas
# City not found. Skipping...
# Processing Record 23 of Set 3 | mys shmidta
# Processing Record 24 of Set 3 | emerald
# Processing Record 25 of Set 3 | ginir
# Processing Record 26 of Set 3 | hasaki
# Processing Record 27 of Set 3 | peterhead
# Processing Record 28 of Set 3 | grand river south east
# Processing Record 29 of Set 3 | bila krynytsya
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | faanui
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | donegal
# Processing Record 34 of Set 3 | yulara
# Processing Record 35 of Set 3 | zhigansk
# Processing Record 36 of Set 3 | pangody
# City not found. Skipping...
# Processing Record 37 of Set 3 | kruisfontein
# Processing Record 38 of Set 3 | moron
# Processing Record 39 of Set 3 | agnibilekrou
# Processing Record 40 of Set 3 | kupang
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 3 | necochea
# Processing Record 42 of Set 3 | leshukonskoye
# Processing Record 43 of Set 3 | banda aceh
# Processing Record 44 of Set 3 | hithadhoo
# Processing Record 45 of Set 3 | zhengjiatun
# Processing Record 46 of Set 3 | humboldt
# Processing Record 47 of Set 3 | ilo
# Processing Record 48 of Set 3 | qaanaaq
# Processing Record 49 of Set 3 | seoul
# City not found. Skipping...
# Processing Record 50 of Set 3 | dogbo
# ------------------------------------
# Processing Record 1 of Set 4 | high level
# Processing Record 2 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 4 | lagoa
# Processing Record 4 of Set 4 | tiarei
# Processing Record 5 of Set 4 | muroto
# Processing Record 6 of Set 4 | palmer
# Processing Record 7 of Set 4 | esil
# Processing Record 8 of Set 4 | cayenne
# Processing Record 9 of Set 4 | kahului
# Processing Record 10 of Set 4 | khorixas
# Processing Record 11 of Set 4 | lasa
# Processing Record 12 of Set 4 | sinjar
# Processing Record 13 of Set 4 | kintampo
# Processing Record 14 of Set 4 | nova olimpia
# Processing Record 15 of Set 4 | lompoc
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 4 | leningradskiy
# Processing Record 17 of Set 4 | trairi
# Processing Record 18 of Set 4 | teguise
# Processing Record 19 of Set 4 | vila franca do campo
# Processing Record 20 of Set 4 | nokaneng
# Processing Record 21 of Set 4 | georgetown
# City not found. Skipping...
# Processing Record 22 of Set 4 | khani
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | sungai kolok
# Processing Record 25 of Set 4 | jumla
# Processing Record 26 of Set 4 | whitehorse
# Processing Record 27 of Set 4 | montemor-o-novo
# Processing Record 28 of Set 4 | nhulunbuy
# Processing Record 29 of Set 4 | haaltert
# Processing Record 30 of Set 4 | cidreira
# Processing Record 31 of Set 4 | dharchula
# Processing Record 32 of Set 4 | balaguer
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 4 | chulman
# Processing Record 34 of Set 4 | sao filipe
# Processing Record 35 of Set 4 | kavieng
# Processing Record 36 of Set 4 | dromolaxia
# Processing Record 37 of Set 4 | mehamn
# Processing Record 38 of Set 4 | clyde river
# City not found. Skipping...
# Processing Record 39 of Set 4 | xinzhou
# Processing Record 40 of Set 4 | lazaro cardenas
# Processing Record 41 of Set 4 | maragogi
# Processing Record 42 of Set 4 | qui nhon
# Processing Record 43 of Set 4 | tigil
# Processing Record 44 of Set 4 | hambantota
# Processing Record 45 of Set 4 | kangaatsiaq
# Processing Record 46 of Set 4 | kaitangata
# City not found. Skipping...
# Processing Record 47 of Set 4 | raahe
# Processing Record 48 of Set 4 | alvorada
# Processing Record 49 of Set 4 | rovaniemi
# Processing Record 50 of Set 4 | yar-sale
# ------------------------------------
# Processing Record 1 of Set 5 | kamwenge
# Processing Record 2 of Set 5 | tual
# Processing Record 3 of Set 5 | castro
# Processing Record 4 of Set 5 | tazovskiy
# Processing Record 5 of Set 5 | bambous virieux
# Processing Record 6 of Set 5 | baker city
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 5 | westport
# Processing Record 8 of Set 5 | hauterive
# Processing Record 9 of Set 5 | beoumi
# Processing Record 10 of Set 5 | srednekolymsk
# Processing Record 11 of Set 5 | buribay
# Processing Record 12 of Set 5 | sun city west
# Processing Record 13 of Set 5 | sechura
# Processing Record 14 of Set 5 | wajid
# Processing Record 15 of Set 5 | varnavino
# Processing Record 16 of Set 5 | kirakira
# Processing Record 17 of Set 5 | aksu
# Processing Record 18 of Set 5 | berlevag
# Processing Record 19 of Set 5 | lebu
# Processing Record 20 of Set 5 | somerset west
# Processing Record 21 of Set 5 | madisonville
# Processing Record 22 of Set 5 | balabac
# Processing Record 23 of Set 5 | fershampenuaz
# Processing Record 24 of Set 5 | faya
# Processing Record 25 of Set 5 | paamiut
# Processing Record 26 of Set 5 | port hawkesbury
# Processing Record 27 of Set 5 | puerto del rosario
# Processing Record 28 of Set 5 | orlik
# Processing Record 29 of Set 5 | san carlos de bariloche
# Processing Record 30 of Set 5 | victoria
# City not found. Skipping...
# Processing Record 31 of Set 5 | nanortalik
# Processing Record 32 of Set 5 | pokhara
# Processing Record 33 of Set 5 | tamiahua
# Processing Record 34 of Set 5 | portland
# Processing Record 35 of Set 5 | champerico
# Processing Record 36 of Set 5 | andra
# Processing Record 37 of Set 5 | calvinia
# Processing Record 38 of Set 5 | awbari
# Processing Record 39 of Set 5 | nioro
# Processing Record 40 of Set 5 | mahibadhoo
# Processing Record 41 of Set 5 | havoysund
# Processing Record 42 of Set 5 | sisimiut
# Processing Record 43 of Set 5 | vostok
# Processing Record 44 of Set 5 | altay
# Processing Record 45 of Set 5 | saskylakh
# Processing Record 46 of Set 5 | cochrane
# City not found. Skipping...
# Processing Record 47 of Set 5 | dikson
# Processing Record 48 of Set 5 | umtata
# Processing Record 49 of Set 5 | kabwe
# Processing Record 50 of Set 5 | namibe
# ------------------------------------
# Processing Record 1 of Set 6 | poum
# City not found. Skipping...
# Processing Record 2 of Set 6 | zlatograd
# Processing Record 3 of Set 6 | saint-pierre
# Processing Record 4 of Set 6 | nouadhibou
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | podgornoye
# Processing Record 7 of Set 6 | igarka
# Processing Record 8 of Set 6 | dasoguz
# Processing Record 9 of Set 6 | toora-khem
# Processing Record 10 of Set 6 | ahuimanu
# Processing Record 11 of Set 6 | angoram
# Processing Record 12 of Set 6 | grand gaube
# Processing Record 13 of Set 6 | mbeya
# Processing Record 14 of Set 6 | atikokan
# City not found. Skipping...
# Processing Record 15 of Set 6 | plouzane
# City not found. Skipping...
# Processing Record 16 of Set 6 | labuhan
# Processing Record 17 of Set 6 | fukue
# Processing Record 18 of Set 6 | lisala
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 6 | chancay
# Processing Record 20 of Set 6 | mirnyy
# City not found. Skipping...
# Processing Record 21 of Set 6 | salalah
# Processing Record 22 of Set 6 | qaqortoq
# City not found. Skipping...
# Processing Record 23 of Set 6 | khandagayty
# Processing Record 24 of Set 6 | grants pass
# Processing Record 25 of Set 6 | komsomolskiy
# Processing Record 26 of Set 6 | heze
# Processing Record 27 of Set 6 | pula
# Processing Record 28 of Set 6 | katsuura
# Processing Record 29 of Set 6 | bontang
# Processing Record 30 of Set 6 | sola
# Processing Record 31 of Set 6 | goderich
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 6 | swan hill
# Processing Record 33 of Set 6 | saint-georges
# Processing Record 34 of Set 6 | djibo
# Processing Record 35 of Set 6 | kherson
# Processing Record 36 of Set 6 | ballina
# Processing Record 37 of Set 6 | talnakh
# Processing Record 38 of Set 6 | huilong
# City not found. Skipping...
# Processing Record 39 of Set 6 | snyder
# Processing Record 40 of Set 6 | green river
# Processing Record 41 of Set 6 | fairbanks
# Processing Record 42 of Set 6 | tiksi
# Processing Record 43 of Set 6 | nueva loja
# Processing Record 44 of Set 6 | boysun
# Processing Record 45 of Set 6 | mount isa
# Processing Record 46 of Set 6 | whangarei
# Processing Record 47 of Set 6 | tiznit
# Processing Record 48 of Set 6 | perth
# Processing Record 49 of Set 6 | lumding
# City not found. Skipping...
# Processing Record 50 of Set 6 | tanout
# ------------------------------------
# Processing Record 1 of Set 7 | cabo san lucas
# Processing Record 2 of Set 7 | richards bay
# Processing Record 3 of Set 7 | alta floresta
# Processing Record 4 of Set 7 | akdepe
# City not found. Skipping...
# Processing Record 5 of Set 7 | shillong
# Processing Record 6 of Set 7 | shar
# Processing Record 7 of Set 7 | presidente epitacio
# Processing Record 8 of Set 7 | san miguel de cauri
# Processing Record 9 of Set 7 | tbilisskaya
# Processing Record 10 of Set 7 | ilulissat
# Processing Record 11 of Set 7 | bakchar
# City not found. Skipping...
# Processing Record 12 of Set 7 | miyako
# City not found. Skipping...
# Processing Record 13 of Set 7 | kodinsk
# Processing Record 14 of Set 7 | bloomington
# Processing Record 15 of Set 7 | nyurba
# Processing Record 16 of Set 7 | buin
# Processing Record 17 of Set 7 | aitape
# Processing Record 18 of Set 7 | pevek
# Processing Record 19 of Set 7 | culaman
# Processing Record 20 of Set 7 | bandarbeyla
# Processing Record 21 of Set 7 | yerbogachen
# Processing Record 22 of Set 7 | texarkana
# Processing Record 23 of Set 7 | birao
# Processing Record 24 of Set 7 | cheney
# City not found. Skipping...
# Processing Record 25 of Set 7 | springdale
# Processing Record 26 of Set 7 | aksay
# City not found. Skipping...
# Processing Record 27 of Set 7 | husavik
# Processing Record 28 of Set 7 | nanakuli
# Processing Record 29 of Set 7 | amga
# Processing Record 30 of Set 7 | paka
# Processing Record 31 of Set 7 | aklavik
# Processing Record 32 of Set 7 | jiuquan
# Processing Record 33 of Set 7 | basoko
# Processing Record 34 of Set 7 | college
# Processing Record 35 of Set 7 | esperance
# Processing Record 36 of Set 7 | vanimo
# Processing Record 37 of Set 7 | kualakapuas
# Processing Record 38 of Set 7 | luderitz
# Processing Record 39 of Set 7 | pinega
# Processing Record 40 of Set 7 | ferrol
# Processing Record 41 of Set 7 | port blair
# Processing Record 42 of Set 7 | alofi
# Processing Record 43 of Set 7 | dickson
# City not found. Skipping...
# Processing Record 44 of Set 7 | garowe
# Processing Record 45 of Set 7 | garchitorena
# Processing Record 46 of Set 7 | kaeo
# Processing Record 47 of Set 7 | sioux lookout
# Processing Record 48 of Set 7 | tazmalt
# Processing Record 49 of Set 7 | torbay
# Processing Record 50 of Set 7 | sambava
# ------------------------------------
# Processing Record 1 of Set 8 | narsaq
# Processing Record 2 of Set 8 | lethem
# Processing Record 3 of Set 8 | adzope
# City not found. Skipping...
# Processing Record 4 of Set 8 | mana
# Processing Record 5 of Set 8 | raudeberg
# Processing Record 6 of Set 8 | puerto leguizamo
# City not found. Skipping...
# Processing Record 7 of Set 8 | kudahuvadhoo
# Processing Record 8 of Set 8 | kantemirovka
# Processing Record 9 of Set 8 | aktau
# Processing Record 10 of Set 8 | aguia branca
# Processing Record 11 of Set 8 | adeje
# Processing Record 12 of Set 8 | carman
# City not found. Skipping...
# Processing Record 13 of Set 8 | fort-shevchenko
# Processing Record 14 of Set 8 | byron bay
# Processing Record 15 of Set 8 | shimoda
# Processing Record 16 of Set 8 | burnie
# Processing Record 17 of Set 8 | tessalit
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | kirensk
# Processing Record 20 of Set 8 | samarai
# Processing Record 21 of Set 8 | san cristobal
# Processing Record 22 of Set 8 | camacha
# Processing Record 23 of Set 8 | loiza
# Processing Record 24 of Set 8 | north platte
# Processing Record 25 of Set 8 | lumut
# Processing Record 26 of Set 8 | laguna
# Processing Record 27 of Set 8 | lakatoro
# Processing Record 28 of Set 8 | east valencia
# Processing Record 29 of Set 8 | auki
# Processing Record 30 of Set 8 | sao joao da barra
# City not found. Skipping...
# Processing Record 31 of Set 8 | severo-kurilsk
# City not found. Skipping...
# Processing Record 32 of Set 8 | wageningen
# Processing Record 33 of Set 8 | comodoro rivadavia
# Processing Record 34 of Set 8 | jiaozuo
# Processing Record 35 of Set 8 | souillac
# Processing Record 36 of Set 8 | mayo
# Processing Record 37 of Set 8 | santa isabel
# Processing Record 38 of Set 8 | isabela
# Processing Record 39 of Set 8 | nizwa
# Processing Record 40 of Set 8 | mandalgovi
# Processing Record 41 of Set 8 | uvalde
# Processing Record 42 of Set 8 | salamanca
# Processing Record 43 of Set 8 | chokurdakh
# Processing Record 44 of Set 8 | musoma
# Processing Record 45 of Set 8 | hokitika
# Processing Record 46 of Set 8 | caravelas
# Processing Record 47 of Set 8 | dankov
# Processing Record 48 of Set 8 | rio gallegos
# Processing Record 49 of Set 8 | hami
# Processing Record 50 of Set 8 | changji
# ------------------------------------
# Processing Record 1 of Set 9 | grindavik
# City not found. Skipping...
# Processing Record 2 of Set 9 | yangambi
# Processing Record 3 of Set 9 | ensley
# Processing Record 4 of Set 9 | kainantu
# Processing Record 5 of Set 9 | cockburn town
# City not found. Skipping...
# Processing Record 6 of Set 9 | bulawayo
# Processing Record 7 of Set 9 | denpasar
# Processing Record 8 of Set 9 | tateyama
# Processing Record 9 of Set 9 | vao
# Processing Record 10 of Set 9 | abha
# Processing Record 11 of Set 9 | azuaga
# Processing Record 12 of Set 9 | balkhash
# Processing Record 13 of Set 9 | sept-iles
# City not found. Skipping...
# Processing Record 14 of Set 9 | pacific grove
# Processing Record 15 of Set 9 | puerto colombia
# Processing Record 16 of Set 9 | toppenish
# Processing Record 17 of Set 9 | tautira
# City not found. Skipping...
# Processing Record 18 of Set 9 | veraval
# Processing Record 19 of Set 9 | dunedin
# Processing Record 20 of Set 9 | isla mujeres
# Processing Record 21 of Set 9 | geraldton
# City not found. Skipping...
# Processing Record 22 of Set 9 | jiamusi
# City not found. Skipping...
# Processing Record 23 of Set 9 | yuci
# Processing Record 24 of Set 9 | taoudenni
# City not found. Skipping...
# Processing Record 25 of Set 9 | sayyan
# Processing Record 26 of Set 9 | novokizhinginsk
# Processing Record 27 of Set 9 | bulgan
# City not found. Skipping...
# Processing Record 28 of Set 9 | mareeba
# Processing Record 29 of Set 9 | itoman
# Processing Record 30 of Set 9 | yaan
# City not found. Skipping...
# Processing Record 31 of Set 9 | rawson
# Processing Record 32 of Set 9 | dudinka
# Processing Record 33 of Set 9 | narok
# Processing Record 34 of Set 9 | broome
# Processing Record 35 of Set 9 | vardo
# Processing Record 36 of Set 9 | takaka
# Processing Record 37 of Set 9 | liberal
# City not found. Skipping...
# Processing Record 38 of Set 9 | aykhal
# City not found. Skipping...
# Processing Record 39 of Set 9 | ghoti
# Processing Record 40 of Set 9 | cherskiy
# Processing Record 41 of Set 9 | basco
# Processing Record 42 of Set 9 | high rock
# Processing Record 43 of Set 9 | mapua
# Processing Record 44 of Set 9 | ancud
# Processing Record 45 of Set 9 | pisco
# City not found. Skipping...
# Processing Record 46 of Set 9 | batagay-alyta
# Processing Record 47 of Set 9 | sitka
# Processing Record 48 of Set 9 | san patricio
# Processing Record 49 of Set 9 | neuquen
# Processing Record 50 of Set 9 | mandera
# ------------------------------------
# Processing Record 1 of Set 10 | liverpool
# Processing Record 2 of Set 10 | sawtell
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 10 | fuling
# Processing Record 4 of Set 10 | lexington
# Processing Record 5 of Set 10 | flinders
# Processing Record 6 of Set 10 | morros
# Processing Record 7 of Set 10 | alto araguaia
# Processing Record 8 of Set 10 | sindgi
# Processing Record 9 of Set 10 | neiafu
# Processing Record 10 of Set 10 | blyth
# Processing Record 11 of Set 10 | szabadszallas
# City not found. Skipping...
# Processing Record 12 of Set 10 | acapulco
# Processing Record 13 of Set 10 | meadow lake
# Processing Record 14 of Set 10 | linxia
# Processing Record 15 of Set 10 | penzance
# Processing Record 16 of Set 10 | asyut
# Processing Record 17 of Set 10 | kaseda
# Processing Record 18 of Set 10 | wilmington
# Processing Record 19 of Set 10 | maniitsoq
# Processing Record 20 of Set 10 | dawei
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 10 | madang
# Processing Record 22 of Set 10 | butka
# Processing Record 23 of Set 10 | matelandia
# Processing Record 24 of Set 10 | namatanai
# Processing Record 25 of Set 10 | verkhnyaya inta
# Processing Record 26 of Set 10 | bulaevo
# Processing Record 27 of Set 10 | padang
# Processing Record 28 of Set 10 | nouakchott
# Processing Record 29 of Set 10 | barranquilla
# Processing Record 30 of Set 10 | yumen
# Processing Record 31 of Set 10 | adrar
# City not found. Skipping...
# Processing Record 32 of Set 10 | nuuk
# City not found. Skipping...
# Processing Record 33 of Set 10 | soure
# Processing Record 34 of Set 10 | lipin bor
# Processing Record 35 of Set 10 | napasar
# Processing Record 36 of Set 10 | grand-lahou
# Processing Record 37 of Set 10 | kokopo
# Processing Record 38 of Set 10 | phan thiet
# Processing Record 39 of Set 10 | dehui
# Processing Record 40 of Set 10 | coahuayana
# Processing Record 41 of Set 10 | yilan
# Processing Record 42 of Set 10 | iquique
# Processing Record 43 of Set 10 | guerrero negro
# Processing Record 44 of Set 10 | itarema
# Processing Record 45 of Set 10 | saint-denis
# Processing Record 46 of Set 10 | kinshasa
# Processing Record 47 of Set 10 | tacuarembo
# Processing Record 48 of Set 10 | katghora
# City not found. Skipping...
# Processing Record 49 of Set 10 | gillette
# Processing Record 50 of Set 10 | gemena
# ------------------------------------
# Processing Record 1 of Set 11 | valparaiso
# City not found. Skipping...
# Processing Record 2 of Set 11 | carahue
# Processing Record 3 of Set 11 | huanren
# Processing Record 4 of Set 11 | wattegama
# Processing Record 5 of Set 11 | powell river
# Processing Record 6 of Set 11 | sivas
# Processing Record 7 of Set 11 | pokosnoye
# Processing Record 8 of Set 11 | ordzhonikidze
# Processing Record 9 of Set 11 | tongzi
# Processing Record 10 of Set 11 | albanel
# Processing Record 11 of Set 11 | navahrudak
# Processing Record 12 of Set 11 | tarrega
# Processing Record 13 of Set 11 | kalga
# Processing Record 14 of Set 11 | anadyr
# Processing Record 15 of Set 11 | jardim
# Processing Record 16 of Set 11 | northam
# Processing Record 17 of Set 11 | puerto baquerizo moreno
# Processing Record 18 of Set 11 | polovinnoye
# City not found. Skipping...
# Processing Record 19 of Set 11 | sao felix do xingu
# Processing Record 20 of Set 11 | ajdabiya
# Processing Record 21 of Set 11 | watertown
# City not found. Skipping...
# Processing Record 22 of Set 11 | marsala
# Processing Record 23 of Set 11 | keroka
# Processing Record 24 of Set 11 | chumikan
# Processing Record 25 of Set 11 | chicama
# Processing Record 26 of Set 11 | alcanede
# City not found. Skipping...
# ------------------------------------
# Data Retrieval Complete
# ------------------------------------

# %%
# Create dictionary for the data collected above

weather_data = {
    "City" : city_list,
    "Cloudiness" : cloudiness_list,
    "Country" : country_list,
    "Date" : date_list, 
    "Humidity" : humidity_list,   
    "Lat" : lat_list,           
    "Lng" : lng_list,         
    "Max Temp" : max_temp_list,      
    "Wind Speed" : wind_speed_list
}

# Convert data into a data frame

weather_df = pd.DataFrame(weather_data)

# Display the first few rows to check data

weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    ushuaia          40      AR  1569303867        81 -54.81  -68.31
# 1      kapaa          90      US  1569303701        83  22.08 -159.32
# 2  kavaratti          75      IN  1569303892        79  10.57   72.64
# 3    rikitea          74      PF  1569303892        72 -23.12 -134.97
# 4     weinan           0      CN  1569303893        60  34.50  109.46
#
#    Max Temp  Wind Speed
# 0     44.60        5.82
# 1     80.60        6.93
# 2     84.20        4.70
# 3     69.89       12.80
# 4     78.01        2.24

# %%
# Output File (CSV) 

output_data_file = "output_data/cities_weather_data.csv"

weather_df.to_csv(output_data_file)

# %%
# Check count of data collected

weather_df.count()
# Out:
# City          526
# Cloudiness    526
# Country       526
# Date          526
# Humidity      526
# Lat           526
# Lng           526
# Max Temp      526
# Wind Speed    526
# dtype: int64
